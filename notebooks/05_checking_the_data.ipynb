# %%
import pandas as pd 

df = pd.read_csv(
    r"C:\\Users\\user\\OneDrive\\Desktop\\financial_regime_clasification\\data\\processed\\xau_with_all_macro.csv"
)

print(df['date'].min())
print(df['date'].max())
print(len(df))

print(df['date'].head())
print(df['date'].tail())
# Out:
# 2025-04-22 03:00:00
# 2025-10-10 15:00:00
# 2942
# 0    2025-04-22 03:00:00
# 1    2025-04-22 04:00:00
# 2    2025-04-22 05:00:00
# 3    2025-04-22 06:00:00
# 4    2025-04-22 07:00:00
# Name: date, dtype: object
# 2937    2025-10-10 11:00:00
# 2938    2025-10-10 12:00:00
# 2939    2025-10-10 13:00:00
# 2940    2025-10-10 14:00:00
# 2941    2025-10-10 15:00:00
# Name: date, dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

print(df['date'].diff().value_counts().head(20))
# Out:
# date
# 0 days 01:00:00    2909
# 2 days 01:00:00      22
# 0 days 03:00:00       5
# 0 days 04:00:00       1
# 0 days 02:00:00       1
# 2 days 03:00:00       1
# 2 days 04:00:00       1
# 0 days 05:00:00       1
# Name: count, dtype: int64

# %% [markdown]
# dataset looks healthy.
